# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil0264/Collab_special/blob/main/RAG_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
from langchain_community.document_loaders import TextLoader
# Out:
# /tmp/ipykernel_829/2929458509.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader('/content/abc.txt',encoding='utf-8')
docs = loader.load()

# %%
from IPython.display import display, Markdown
display(Markdown(docs[0].page_content))
# Out:
# If you mean why the Indian women’s cricket team refused to take the Asia Cup trophy from Pakistan’s Mohsin Naqvi:
#
# India won the Women’s Asia Cup 2026, beating Sri Lanka by 72 runs. 
# Mohsin Naqvi is the president of the Asian Cricket Council (ACC) and also heads Pakistan cricket.
# During the trophy presentation, the Indian team did not accept the trophy from him. Reports say this was a BCCI/team decision connected to the ongoing India–Pakistan tensions.
# India had taken a similar position during the men’s Asia Cup 2025, when the men’s team also refused to receive the trophy from Naqvi.
# The exact reason was not publicly explained in detail by the players, so claims about a specific personal reason should be treated cautiously.
#
# So, basically, it was a protest/official stance regarding Naqvi and the broader India–Pakistan political tensions, rather than the Indian team refusing the championship itself.

# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
import json

# %%
from google.colab import userdata
groq_api_key = userdata.get('GroqAPI')

# %%
llm = ChatGroq(
    model="Qwen/Qwen3.8-27B",
    groq_api_key=groq_api_key, # Use the API key loaded from userdata
    temperature=0,
    max_tokens=256,
)

# %%
response = llm.invoke("What is the capital of United States")

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_829/1630217422.py in <cell line: 0>()
# ----> 1 response = llm.invoke("What is the capital of United States")
#       2
#       3 print(response.content)
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     486             cast(
#     487                 "ChatGeneration",
# --> 488                 self.generate_prompt(
#     489                     [self._convert_input(input)],
#     490                     stop=stop,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1875     ) -> LLMResult:
#    1876         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
# !pip install -q langchain-huggingface

# %%
# !pip install -qU  langchain-huggingface text-generation transformers google-search-results numexpr langchainhub sentencepiece jinja2 bitsandbytes accelerate
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# ...

# %%
print('Upgrading huggingface_hub to a compatible version...')
# !pip install -U huggingface_hub
print('huggingface_hub upgrade complete.')

# %%
print('Installing huggingface_hub>=0.24.0...')
# !pip install -U huggingface_hub>=0.24.0
print('huggingface_hub installation complete.')
# Out:
# Installing huggingface_hub>=0.24.0...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.57.6 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 1.31.0 which is incompatible.
# text-generation 0.7.0 requires huggingface-hub<1.0,>=0.12, but you have huggingface-hub 1.31.0 which is incompatible.
# huggingface_hub installation complete.

# %%
print('Downgrading huggingface_hub to a compatible version (0.36.2)...')
# !pip install -U huggingface_hub==0.36.2
print('huggingface_hub downgrade complete.')
# Out:
# Downgrading huggingface_hub to a compatible version (0.36.2)...
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.31.0
#     Uninstalling huggingface_hub-1.31.0:
#       Successfully uninstalled huggingface_hub-1.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gradio 6.26.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.
# ...
# huggingface_hub downgrade complete.

# %% [markdown]
# After downgrading `huggingface_hub`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the correct library version is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again with the newly downgraded `huggingface_hub`.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_829/4087290651.py in <cell line: 0>()
# ----> 1 response = chat_model.invoke("what is the capital of india ?")
#       2 print(response.content)
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     486             cast(
#     487                 "ChatGeneration",
# --> 488                 self.generate_prompt(
#     489                     [self._convert_input(input)],
#     490                     stop=stop,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1875     ) -> LLMResult:
#    1876         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
print('Upgrading langchain-huggingface...')
# !pip install -U langchain-huggingface
print('langchain-huggingface upgrade complete.')

# %% [markdown]
# After upgrading `langchain-huggingface`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the new library is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again after the `langchain-huggingface` upgrade.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)

# %%
print('Upgrading langchain-huggingface...')
# !pip install -U langchain-huggingface
print('langchain-huggingface upgrade complete.')

# %% [markdown]
# After upgrading `langchain-huggingface`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the new library is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again after the `langchain-huggingface` upgrade.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)

# %%
print('Upgrading langchain-huggingface...')
# !pip install -U langchain-huggingface
print('langchain-huggingface upgrade complete.')

# %% [markdown]
# After upgrading `langchain-huggingface`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the new library is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again after the `langchain-huggingface` upgrade.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)

# %% [markdown]
# After upgrading `huggingface_hub`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the new library is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again with the updated `huggingface_hub`.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_829/4087290651.py in <cell line: 0>()
# ----> 1 response = chat_model.invoke("what is the capital of india ?")
#       2 print(response.content)
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     486             cast(
#     487                 "ChatGeneration",
# --> 488                 self.generate_prompt(
#     489                     [self._convert_input(input)],
#     490                     stop=stop,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1875     ) -> LLMResult:
#    1876         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
print('Downgrading huggingface_hub to a compatible version (0.36.2)...')
# !pip install -U huggingface_hub==0.36.2
print('huggingface_hub downgrade complete.')
# Out:
# Downgrading huggingface_hub to a compatible version (0.36.2)...
# ...
# huggingface_hub downgrade complete.

# %% [markdown]
# After downgrading `huggingface_hub`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the correct library version is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again with the newly downgraded `huggingface_hub`.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)
# Out:
# <think>
# Okay, the user is asking about the capital of India. That seems straightforward. Let me recall the current capital—it's New Delhi. But wait, I should make sure there's no confusion with Delhi itself. People sometimes mix up Delhi and New Delhi.
#
# Hmm, the user might be a student doing homework or someone preparing for a quiz. Maybe they need a quick answer without extra details. But perhaps they also want to know why it's called New Delhi or its significance. Should I mention that it's part of the National Capital Territory?
#
# I wonder if they're asking because of travel plans. If so, adding a bit about its role as the government center could be useful. But since the question is direct, I'll keep it concise. Just state New Delhi clearly, and briefly explain its location within Delhi. No need for history unless they ask more.
#
# ...

# %%
print('Upgrading langchain-huggingface...')
# !pip install -U langchain-huggingface
print('langchain-huggingface upgrade complete.')

# %% [markdown]
# After upgrading `langchain-huggingface`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the new library is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again after the `langchain-huggingface` upgrade.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)

# %%
print('Downgrading huggingface_hub to a compatible version (0.36.2)...')
# !pip install -U huggingface_hub==0.36.2
print('huggingface_hub downgrade complete.')
# Out:
# Downgrading huggingface_hub to a compatible version (0.36.2)...
# ...
# ERROR: Operation cancelled by user
# ^C

# %% [markdown]
# After downgrading `huggingface_hub`, we need to re-initialize the HuggingFace endpoint and chat model to ensure the correct library version is used.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again with the newly downgraded `huggingface_hub`.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)
# Out:
# <think>
# Okay, the user is asking about the capital of India. That's a straightforward geography question.
#
# Hmm, I recall that New Delhi is the capital, but let me double-check to be absolutely sure. Yes, confirmed - India's capital is New Delhi, which is part of the larger National Capital Territory of Delhi.
#
# The user didn't provide any context about why they're asking. Maybe they're a student doing homework, a traveler planning a trip, or just someone curious about world capitals. Since it's such a basic fact, they might be very young or new to geography.
#
# I should keep the answer simple and precise. No need for extra details unless they ask follow-ups. The response should be clear and direct: "The capital of India is New Delhi."
#
# I wonder if they'll ask about other Indian cities next? Or perhaps about why New Delhi was chosen as capital? But for now, just answering the question as asked seems best.
# </think>
# The capital of India is **New Delhi**.
#
# ...

# %% [markdown]
# After upgrading `huggingface_hub`, we need to re-initialize the HuggingFace endpoint and chat model.

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Now, let's try invoking the chat model again.

# %%
response = chat_model.invoke("what is the capital of india ?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_829/4087290651.py in <cell line: 0>()
# ----> 1 response = chat_model.invoke("what is the capital of india ?")
#       2 print(response.content)
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     486             cast(
#     487                 "ChatGeneration",
# --> 488                 self.generate_prompt(
#     489                     [self._convert_input(input)],
#     490                     stop=stop,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1875     ) -> LLMResult:
#    1876         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint

from langchain_huggingface import ChatHuggingFace
import getpass
import os

if not os.getenv("HUGGINGFACEHUB_API_TOKEN"):
    os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get("HF_TOKEN")


from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
)

chat_model = ChatHuggingFace(llm=llm)

# %%
response = chat_model.invoke("what is the capital of india ?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_829/124453089.py in <cell line: 0>()
# ----> 1 response = chat_model.invoke("what is the capital of india ?")
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     486             cast(
#     487                 "ChatGeneration",
# --> 488                 self.generate_prompt(
#     489                     [self._convert_input(input)],
#     490                     stop=stop,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1875     ) -> LLMResult:
#    1876         prompt_messages = [p.to_messages() for p in prompts]
# -> 1877         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
# ...
